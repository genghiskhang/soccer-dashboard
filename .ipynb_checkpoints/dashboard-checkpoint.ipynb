# %%
# Pandas, Plotly, and NumPy modules
import dash
from dash import dcc
from dash import html
import plotly.express as px
import pandas as pd

# Modules imported to retrieve data from Google Sheets
import gspread
from df2gspread import  df2gspread as d2g
from oauth2client.service_account import ServiceAccountCredentials

# Spreadsheet Info
SPREADSHEET_ID = '1-kUlYLeDEQyzw2PYnLn6quq7kFYJbduI_Zrk_bQ7_9A'
RANGE_NAME = 'PlayerOllie'

# HTML Colors
navy = '#0C0552'
gray = '#717079'

def layout():
    
    return html.Div(className='body', children=[
                html.Div(className='title', children=[
                    html.H1('James Knowlton', style={
                        'color':navy
                    }),
                    html.H2('Player Report', style={
                        'color':navy
                    })
                ]),
                html.Div(className='stats', children=[
                    html.Div(className='offense', children=[
                        html.H2('Offense', style={
                            'color':navy,
                            'textAlign':'center'
                        }),
                        html.Ul(className='stats-list', children=[
                            html.Li('Goals: '),
                            html.Li('Shots: '),
                            html.Li('Shots on Goal: '),
                            html.Li('Assists: '),
                            html.Li('Passes: '),
                            html.Li('Success Rate with Ball: '),
                            html.Li('Turnovers: ')
                        ], style={
                            'listStyle':'none',
                            'padding':0,
                            'flex':1,
                            'color':gray
                        })
                    ]),
                    html.Div(className='defense', children=[
                        html.H2('Defense', style={
                            'color':navy,
                            'textAlign':'center'
                        }),
                        html.Ul(className='stats-list', children=[
                            html.Li('Fouls: '),
                            html.Li('Recoveries: '),
                            html.Li('Yellow Cards: '),
                            html.Li('Red Cards: ')
                        ], style={
                            'listStyle':'none',
                            'padding':0,
                            'flex':1,
                            'color':gray
                        })
                    ]),
                    html.Div(className='work', children=[
                        html.H2('Work', style={
                            'color':navy,
                            'textAlign':'center'
                        }),
                        html.Ul(className='stats-list', children=[
                            html.Li('Participation %: '),
                            html.Li('Passes Completed: '),
                            html.Li('Two Mile (seconds): ')
                        ], style={
                            'listStyle':'none',
                            'padding':0,
                            'flex':1,
                            'color':gray
                        })
                    ])
                ], style={
                    'display':'flex',
                    'gap':50
                }),
                html.Div(className='radial-position-container', children=[
                    html.Div(className='radial', children=[
                        html.Div(className='radial-chart', children=[
                            html.P('Insert Radial Here')
                        ]),
                        html.Div(className='radial-stats', children=[

                        ])
                    ]),
                    html.Div(className='position', children=[
                        html.P('Insert Position Here')
                    ])
                ], style={
                    'display':'flex',
                    'gap':50
                }),
                html.Div(className='line-chart', children=[
                    html.P('Insert Line Here')
                ])
            ], style={
                'fontFamily':'Oswald, sans-serif'
            })

app = dash.Dash(__name__)

app.layout = layout()

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15980/2382710725.py in <module>
#     113 app = dash.Dash(__name__)
#     114
# --> 115 app.layout = layout()
#     116
#     117 if __name__ == '__main__':
#
# ~\AppData\Local\Temp/ipykernel_15980/2382710725.py in layout()
#      34                         html.H2('Offense', style={
#      35                             'color':navy,
# ---> 36                             'textAlign':center
#      37                         }),
#      38                         html.Ul(className='stats-list', children=[
#
# NameError: name 'center' is not defined
